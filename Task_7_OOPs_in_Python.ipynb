# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhuvi285/Advanced-GenAI-Internship-Innomatics-Research-Labs/blob/main/Task_7_OOPs_in_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Problem 1: Smart Light Controller**

# %%
class SmartLight:
  #self represents the current object that is calling the method.
  #__init__ is a constructor which automatically runs after creating an object
  def __init__(self , light_name):
    self.light_name = light_name
    self.is_on = False    #Initially in default state it is off

  def turn_on(self):      # Method for setting status to On
    self.is_on = True

  def turn_off(self):     # Method for setting status to Off
    self.is_on = False

  def display_status(self):     # Method for displaying status
    if self.is_on:
      print(f"{self.light_name} is ON")
    else:
        print(f"{self.light_name} is OFF")


light = SmartLight("Bedroom Light")
action = "ON"

#Action that user will perform will checked in this if-elif block
if action == "ON":
  light.turn_on()
elif action == "OFF":
  light.turn_off()


light.display_status()
# Out:
# Bedroom Light is ON

# %% [markdown]
# ### **Problem 2: Employee ID Card System**

# %%
class Employee:
    def __init__(self, name, emp_id, department):
        self.name = name
        self.emp_id = emp_id
        self.department = department

    def display_id_card(self):
        print(f"Employee Name: {self.name}")
        print(f"Employee ID: {self.emp_id}")
        print(f"Department: {self.department}")


# Sample Input
employee = Employee("Rahul", "EMP102", "IT")

# Display ID Card
employee.display_id_card()
# Out:
# Employee Name: Rahul
# Employee ID: EMP102
# Department: IT

# %% [markdown]
# ### **Problem 3: Mobile Contact Record**

# %%
class Contact:
  def __init__(self , name , contact_number):
    self.name = name
    self.contact_number = contact_number

  def display_contact(self):
    print("Contact Saved")
    print(f"Name : {self.name}")
    print(f"Phone: {self.contact_number}")


contact = Contact("Anita" , "9876543210")

contact.display_contact()
# Out:
# Contact Saved
# Name : Anita
# Phone: 9876543210

# %% [markdown]
# ### **Problem 4: Product Price Tag Generator**

# %%
class Product:
    def __init__(self, product_name, price):
        self.product_name = product_name
        self.price = price

    def display_price_tag(self):
        print(f"Product: {self.product_name}")
        print(f"Price: ₹{self.price}")

product = Product("Headphones", 2499)

product.display_price_tag()
# Out:
# Product: Headphones
# Price: ₹2499

# %% [markdown]
# ### **Problem 5: Movie Rating Display System**

# %%
class Movie:
    def __init__(self, movie_name, rating):
        self.movie_name = movie_name
        self.rating = rating

    def display_movie_details(self):
        print(f"Movie: {self.movie_name}")
        print(f"Rating: {self.rating} / 5")

movie = Movie("Inception", 4.8)
movie.display_movie_details()
# Out:
# Movie: Inception
# Rating: 4.8 / 5

# %% [markdown]
# ### **Problem 6: Delivery Address Manager**

# %%
class Delivery:
    def __init__(self, customer_name, address):
        self.customer_name = customer_name
        self.address = address

    def display_delivery_details(self):
        print("Delivery Details")
        print(f"Customer: {self.customer_name}")
        print(f"Address: {self.address}")


delivery = Delivery("Suman", "Hyderabad")

delivery.display_delivery_details()
# Out:
# Delivery Details
# Customer: Suman
# Address: Hyderabad
